# %%
import pandas as pd
df = pd.read_excel("Desktop/py-master/pandas/12_stack/stocks_3_levels.xlsx",header=[0,1])
df
# Out:
#   Unnamed: 0_level_0 Price Ratios                     \
#   Unnamed: 0_level_1        Price Price.1    Price.2
# 0            Company     Facebook  Google  Microsoft
# 1            Q1 2016          155     955         66
# 2            Q2 2016          150     987         69
# 3            Q3 2016          153     963         62
# 4            Q4 2016          155    1000         61
# 5            Q1 2017          156    1012         66
#
#                                                                  \
#   Price to earnings ratio (P/E) Price to earnings ratio (P/E).1
# 0                      Facebook                          Google
# 1                          37.1                              32
# 2                         36.98                            31.3
# 3                         36.78                            31.7
# 4                         36.11                            31.2
# 5                         37.07                              30
#
# ...

# %%
df1 =df.stack()
df1
# Out:
#                                   Income Statement Price Ratios  \
# 0 Net Profit                              Facebook          NaN
#   Net Profit.1                              Google          NaN
#   Net Profit.2                           Microsoft          NaN
#   Net Sales                               Facebook          NaN
#   Net Sales.1                               Google          NaN
# ...                                            ...          ...
# 5 Price to earnings ratio (P/E).1              NaN           30
#   Price to earnings ratio (P/E).2              NaN           31
#   Price.1                                      NaN         1012
#   Price.2                                      NaN           66
#   Unnamed: 0_level_1                           NaN          NaN
#
#                                   Unnamed: 0_level_0
# 0 Net Profit                                     NaN
#   Net Profit.1                                   NaN
# ...

# %%
stacked = df.stack(level=0,dropna=True)
stacked
# Out:
#                      Net Profit Net Profit.1 Net Profit.2 Net Sales  \
# 0 Income Statement     Facebook       Google    Microsoft  Facebook
#   Price Ratios              NaN          NaN          NaN       NaN
#   Unnamed: 0_level_0        NaN          NaN          NaN       NaN
# 1 Income Statement          0.8         5.43         4.56       2.6
#   Price Ratios              NaN          NaN          NaN       NaN
#   Unnamed: 0_level_0        NaN          NaN          NaN       NaN
# 2 Income Statement         0.97         5.89          5.1       3.1
#   Price Ratios              NaN          NaN          NaN       NaN
#   Unnamed: 0_level_0        NaN          NaN          NaN       NaN
# 3 Income Statement          1.2          6.1         5.43       4.3
#   Price Ratios              NaN          NaN          NaN       NaN
#   Unnamed: 0_level_0        NaN          NaN          NaN       NaN
# 4 Income Statement         1.67          6.5         5.89       6.7
# ...

# %%
stacked.unstack()
# Out:
#         Net Profit                                     Net Profit.1  \
#   Income Statement Price Ratios Unnamed: 0_level_0 Income Statement
# 0         Facebook          NaN                NaN           Google
# 1              0.8          NaN                NaN             5.43
# 2             0.97          NaN                NaN             5.89
# 3              1.2          NaN                NaN              6.1
# 4             1.67          NaN                NaN              6.5
# 5             2.03          NaN                NaN              6.4
#
#                                       Net Profit.2               \
#   Price Ratios Unnamed: 0_level_0 Income Statement Price Ratios
# 0          NaN                NaN        Microsoft          NaN
# 1          NaN                NaN             4.56          NaN
# 2          NaN                NaN              5.1          NaN
# 3          NaN                NaN             5.43          NaN
# ...

# %%
df1.unstack()
# Out:
#   Income Statement                                                  \
#         Net Profit Net Profit.1 Net Profit.2 Net Sales Net Sales.1
# 0         Facebook       Google    Microsoft  Facebook      Google
# 1              0.8         5.43         4.56       2.6          20
# 2             0.97         5.89          5.1       3.1          22
# 3              1.2          6.1         5.43       4.3          24
# 4             1.67          6.5         5.89       6.7          26
# 5             2.03          6.4         6.09       8.1          31
#
#                                                    \
#   Net Sales.2 Price Price to earnings ratio (P/E)
# 0   Microsoft   NaN                           NaN
# 1        18.7   NaN                           NaN
# 2        21.3   NaN                           NaN
# 3       21.45   NaN                           NaN
# 4       21.88   NaN                           NaN
# 5       22.34   NaN                           NaN
#
# ...

# %%
df2 = pd.read_excel("Desktop/py-master/pandas/12_stack/stocks_3_levels.xlsx",header=[0,1,2])
df2
# Out:
#   Unnamed: 0_level_0 Price Ratios                   \
#   Unnamed: 0_level_1        Price
#              Company     Facebook Google Microsoft
# 0            Q1 2016          155    955        66
# 1            Q2 2016          150    987        69
# 2            Q3 2016          153    963        62
# 3            Q4 2016          155   1000        61
# 4            Q1 2017          156   1012        66
#
#                                                  Income Statement         \
#   Price to earnings ratio (P/E)                         Net Sales
#                        Facebook Google Microsoft         Facebook Google
# 0                         37.10   32.0     30.31              2.6     20
# 1                         36.98   31.3     30.56              3.1     22
# 2                         36.78   31.7     30.46              4.3     24
# 3                         36.11   31.2     30.11              6.7     26
# ...

# %%
df2.stack(level=2)
# Out:
#             Income Statement           Price Ratios  \
#                   Net Profit Net Sales        Price
# 0 Company                NaN       NaN          NaN
#   Facebook              0.80      2.60        155.0
#   Google                5.43     20.00        955.0
#   Microsoft             4.56     18.70         66.0
# 1 Company                NaN       NaN          NaN
#   Facebook              0.97      3.10        150.0
#   Google                5.89     22.00        987.0
#   Microsoft             5.10     21.30         69.0
# 2 Company                NaN       NaN          NaN
#   Facebook              1.20      4.30        153.0
#   Google                6.10     24.00        963.0
#   Microsoft             5.43     21.45         62.0
# 3 Company                NaN       NaN          NaN
#   Facebook              1.67      6.70        155.0
#   Google                6.50     26.00       1000.0
#   Microsoft             5.89     21.88         61.0
# ...
