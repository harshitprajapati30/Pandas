# %%
import pandas as pd
df = pd.read_csv("Desktop/py-master/pandas/15_ts_date_range/aapl_no_dates.csv")
df
# Out:
#       Open    High     Low   Close    Volume
# 0   153.17  153.33  152.22  153.18  16404088
# 1   153.58  155.45  152.89  155.45  27770715
# 2   154.34  154.45  153.46  153.93  25331662
# 3   153.90  155.81  153.78  154.45  26624926
# 4   155.02  155.98  154.48  155.37  21069647
# 5   155.25  155.54  154.40  154.99  21250798
# 6   155.19  155.19  146.02  148.98  64882657
# 7   145.74  146.09  142.51  145.42  72307330
# 8   147.16  147.45  145.15  146.59  34165445
# 9   147.50  147.50  143.84  145.16  31531232
# 10  143.32  144.48  142.21  144.29  32165373
# 11  143.78  144.50  142.20  142.27  50361093
# 12  143.66  146.74  143.66  146.34  32541404
# 13  146.87  146.87  144.94  145.01  24900073
# 14  145.52  146.07  144.61  145.87  21265751
# 15  145.77  146.70  145.12  145.63  19106294
# 16  145.13  147.16  145.11  146.28  35439389
# 17  147.17  148.28  145.38  145.82  25692361
# 18  145.01  146.16  143.62  143.73  24761891
# 19  144.49  146.11  143.16  145.83  22082432
# ...

# %%
daterange = pd.date_range(start='3/1/2020',end='3/31/2020',freq='B')

# %%
daterange
# Out:
# DatetimeIndex(['2020-03-02', '2020-03-03', '2020-03-04', '2020-03-05',
#                '2020-03-06', '2020-03-09', '2020-03-10', '2020-03-11',
#                '2020-03-12', '2020-03-13', '2020-03-16', '2020-03-17',
#                '2020-03-18', '2020-03-19', '2020-03-20', '2020-03-23',
#                '2020-03-24', '2020-03-25', '2020-03-26', '2020-03-27',
#                '2020-03-30', '2020-03-31'],
#               dtype='datetime64[ns]', freq='B')

# %%
df.set_index(daterange,inplace=True)
df.head()
# Out:
#               Open    High     Low   Close    Volume
# 2020-03-02  153.17  153.33  152.22  153.18  16404088
# 2020-03-03  153.58  155.45  152.89  155.45  27770715
# 2020-03-04  154.34  154.45  153.46  153.93  25331662
# 2020-03-05  153.90  155.81  153.78  154.45  26624926
# 2020-03-06  155.02  155.98  154.48  155.37  21069647

# %%
# %matplotlib inline
df.Close.plot()

# %%
df['2020-03-10':'2020-03-15']
# Out:
#               Open    High     Low   Close    Volume
# 2020-03-10  155.19  155.19  146.02  148.98  64882657
# 2020-03-11  145.74  146.09  142.51  145.42  72307330
# 2020-03-12  147.16  147.45  145.15  146.59  34165445
# 2020-03-13  147.50  147.50  143.84  145.16  31531232

# %%
df['2020-03-10':'2020-03-15'].Close.mean()
# Out:
# 146.5375

# %%
df.asfreq('D',method='pad')#daily basis
# Out:
#               Open    High     Low   Close    Volume
# 2020-03-02  153.17  153.33  152.22  153.18  16404088
# 2020-03-03  153.58  155.45  152.89  155.45  27770715
# 2020-03-04  154.34  154.45  153.46  153.93  25331662
# 2020-03-05  153.90  155.81  153.78  154.45  26624926
# 2020-03-06  155.02  155.98  154.48  155.37  21069647
# 2020-03-07  155.02  155.98  154.48  155.37  21069647
# 2020-03-08  155.02  155.98  154.48  155.37  21069647
# 2020-03-09  155.25  155.54  154.40  154.99  21250798
# 2020-03-10  155.19  155.19  146.02  148.98  64882657
# 2020-03-11  145.74  146.09  142.51  145.42  72307330
# 2020-03-12  147.16  147.45  145.15  146.59  34165445
# 2020-03-13  147.50  147.50  143.84  145.16  31531232
# 2020-03-14  147.50  147.50  143.84  145.16  31531232
# 2020-03-15  147.50  147.50  143.84  145.16  31531232
# 2020-03-16  143.32  144.48  142.21  144.29  32165373
# 2020-03-17  143.78  144.50  142.20  142.27  50361093
# 2020-03-18  143.66  146.74  143.66  146.34  32541404
# ...

# %%
df.asfreq('W',method='pad')#weekly basis
# Out:
#               Open    High     Low   Close    Volume
# 2020-03-08  155.02  155.98  154.48  155.37  21069647
# 2020-03-15  147.50  147.50  143.84  145.16  31531232
# 2020-03-22  145.52  146.07  144.61  145.87  21265751
# 2020-03-29  144.49  146.11  143.16  145.83  22082432

# %%
daterange = pd.date_range(start='3/1/2020',periods=10,freq='B')
daterange
# Out:
# DatetimeIndex(['2020-03-02', '2020-03-03', '2020-03-04', '2020-03-05',
#                '2020-03-06', '2020-03-09', '2020-03-10', '2020-03-11',
#                '2020-03-12', '2020-03-13'],
#               dtype='datetime64[ns]', freq='B')

# %%
import numpy as np
np.random.randint(1,10,len(daterange)) #random number generationa
# Out:
# array([3, 6, 8, 4, 4, 6, 6, 1, 8, 2])

# %%
import numpy as np
ts = pd.Series(np.random.randint(1,10,len(daterange)),index=daterange) #random number generation
ts.head(10)
# Out:
# 2020-03-02    7
# 2020-03-03    7
# 2020-03-04    6
# 2020-03-05    2
# 2020-03-06    7
# 2020-03-09    2
# 2020-03-10    7
# 2020-03-11    7
# 2020-03-12    7
# 2020-03-13    6
# Freq: B, dtype: int64
